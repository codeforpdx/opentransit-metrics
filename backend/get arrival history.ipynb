# %%
import pandas as pd
import datetime

# %%
from models import arrival_history, util, config

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
agency = config.get_agency('trimet')

# %%
agency_id = agency.id
route_id = '4'
version = 'v4c'
start_time_str = '00:00'
end_time_str = '24:00'

# %%
arrival_df = pd.DataFrame()
dates = util.get_dates_in_range('2022-03-10', '2022-03-10')
for date in dates:
    history = arrival_history.get_by_date(agency_id, route_id, date, version)
    stops_data_json = history.stops_data
    if len(stops_data_json) > 0:
        for stop_id in stops_data_json.keys():
            for direction_id in stops_data_json[stop_id]['arrivals'].keys():
        #         print(f"stop_id = {stop_id}, direction_id = {direction_id}")
                one_stop_dir_arrivals = pd.DataFrame(stops_data_json[stop_id]['arrivals'][direction_id])
                one_stop_dir_arrivals['stop_id'] = stop_id
                one_stop_dir_arrivals['direction_id'] = direction_id
                one_stop_dir_arrivals['date'] = date
                if arrival_df.empty:
                    arrival_df = one_stop_dir_arrivals.copy()
                else:
                    arrival_df = arrival_df.append(one_stop_dir_arrivals)
    else:
        print(f"No arrivals for {date}")
        arrivals_df = pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_331/1599258333.py in <module>
#       2 dates = util.get_dates_in_range('2022-03-10', '2022-03-10')
#       3 for date in dates:
# ----> 4     history = arrival_history.get_by_date(agency_id, route_id, date, version)
#       5     stops_data_json = history.stops_data
#       6     if len(stops_data_json) > 0:
#
# /app/backend/models/util.py in inner(*args, **kwargs)
#      10         #     datetime_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#      11         #     f.write(f"{datetime_str} - I'm running this function {func.__name__} in {func.__module__} \n")
# ---> 12         func(*args, **kwargs)
#      13     return inner
#      14
#
# /app/backend/models/arrival_history.py in get_by_date(agency_id, route_id, d, version)
#     182
#     183     try:
# --> 184         mtime = os.stat(cache_path).st_mtime
#     185         now = time.time()
#     186         if now - mtime < 86400:
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
rename_dict = {'t':'time','e':'departure_time','d':'distance','i':'trip_id', 'v':'vehicle_id'}
arrival_w_names_df = arrival_df.rename(columns=rename_dict).copy()

# %%
arrival_w_names_df.head()
# Out:
#          time  departure_time  distance vehicle_id  trip_id stop_id  \
# 0  1646915710      1646915743        16       4232      511   10177
# 1  1646919353      1646919391        15       3004       60   10177
# 2  1646920192      1646920196        14       3640      326   10177
# 3  1646921233      1646921248        15       3231      145   10177
# 4  1646921942      1646921972        10       4041      434   10177
#
#   direction_id        date
# 0            1  2022-03-10
# 1            1  2022-03-10
# 2            1  2022-03-10
# 3            1  2022-03-10
# 4            1  2022-03-10

# %%
arrival_w_names_df.sort_values(['trip_id', 'time'])
# Out:
#            time  departure_time  distance vehicle_id  trip_id stop_id  \
# 3    1646925110      1646925111        56       2801        0    6387
# 3    1646925112      1646925112       243       2801        0   10611
# 3    1646925113      1646925113        50       2801        0    1045
# 2    1646925114      1646925114       106       2801        0      45
# 3    1646925115      1646925115        36       2801        0   12727
# ..          ...             ...       ...        ...      ...     ...
# 103  1646984942      1646984949        13       4232      538    9301
# 124  1646985016      1646985051        11       4232      538    7631
# 116  1646985081      1646985095        10       4232      538    7642
# 112  1646985151      1646985159        10       4232      538    7634
# 107  1646985197      1646985221        24       4232      538   12791
#
#     direction_id        date
# 3              0  2022-03-10
# 3              0  2022-03-10
# 3              0  2022-03-10
# 2              0  2022-03-10
# 3              0  2022-03-10
# ..           ...         ...
# 103            1  2022-03-10
# 124            1  2022-03-10
# 116            1  2022-03-10
# 112            1  2022-03-10
# 107            1  2022-03-10
#
# [11444 rows x 8 columns]
